# %% [markdown]
# ## Practice 3 TESS light curves

# %%
# import libraries
import matplotlib.pyplot as plt
import glob

# Find all .fits files in the current directory
fits_files = glob.glob("*.lc")

for filename in fits_files:
    # Upload the file, assuming it is a .txt or .lc file with space separators    
    df = pd.read_csv(filename, delim_whitespace=True)
    
    # remove NaN
    df = df.dropna(subset=['PDCSAP_FLUX'])
    
    # plot
    plt.figure(figsize=(10, 5))
    plt.errorbar(df['TIME'], df['PDCSAP_FLUX'], yerr=df['PDCSAP_FLUX_ERR'], markersize=3, fmt='.', ecolor='gray', alpha=0.4, color='dimgray')
    plt.xlabel('TIME/BJD - 2457000, days)')
    plt.ylabel('PDCSAP_FLUX/ e-/S')
    # remove the .lc extension from the object name
    plt.title(filename.replace("_lc.lc", ""))
    plt.grid(False)
    plt.legend()
    plt.tight_layout()
    plt.savefig(filename.replace("_lc.lc", ".png"))
    plt.show()
    print(f"Save: {filename.replace("_lc.lc", ".png")}")
# Out:
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Save: tess2023341045131-s0073-0000000002237045-0268-s.png
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Save: tess2023341045131-s0073-0000000002006984-0268-s.png
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Save: tess2023341045131-s0073-0000000002152411-0268-s.png
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Save: tess2023341045131-s0073-0000000002008765-0268-s.png
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Save: tess2023341045131-s0073-0000000001840666-0268-s.png
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Save: tess2023341045131-s0073-0000000002234723-0268-s.png
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Save: tess2023341045131-s0073-0000000001750268-0268-s.png
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Save: tess2023341045131-s0073-0000000002102329-0268-s.png
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Save: tess2023341045131-s0073-0000000002236015-0268-s.png
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Save: tess2023341045131-s0073-0000000002334539-0268-s.png
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Save: tess2023341045131-s0073-0000000002104696-0268-s.png
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Save: tess2023341045131-s0073-0000000002149979-0268-s.png
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Save: tess2023341045131-s0073-0000000001755406-0268-s.png
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Save: tess2023341045131-s0073-0000000001827744-0268-s.png
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Save: tess2023341045131-s0073-0000000001947463-0268-s.png
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Save: tess2023341045131-s0073-0000000002234692-0268-s.png
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Save: tess2023341045131-s0073-0000000002014191-0268-s.png
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Save: tess2023341045131-s0073-0000000001950736-0268-s.png
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Save: tess2023341045131-s0073-0000000001942416-0268-s.png
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/3526399204.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Save: tess2023341045131-s0073-0000000002105589-0268-s.png

# %%
# import libraries
import matplotlib.pyplot as plt
import glob
import pandas as pd
from astropy.stats import sigma_clip
import numpy as np

# Find all .fits files in the current directory
fits_files = glob.glob("*.lc")

for filename in fits_files:
    # Upload the file, assuming it is a .txt or .lc file with space separators    
    df = pd.read_csv(filename, delim_whitespace=True)

    # Remove NaN
    df = df.dropna(subset=['PDCSAP_FLUX'])

    # Apply sigma clipping to detect outliers
    flux_clipped = sigma_clip(df['PDCSAP_FLUX'], sigma=3, maxiters=5)
    outliers = flux_clipped.mask  # Boolean mask: True = outlier

    # Plot
    plt.figure(figsize=(10, 5))
    
    # Plot normal points
    plt.errorbar(df['TIME'][~outliers], df['PDCSAP_FLUX'][~outliers], 
                 yerr=df['PDCSAP_FLUX_ERR'][~outliers], fmt='.', 
                 markersize=3, ecolor='gray', alpha=0.4, color='dimgray', label='Normal')

    # Plot outliers in red
    plt.errorbar(df['TIME'][outliers], df['PDCSAP_FLUX'][outliers], 
                 yerr=df['PDCSAP_FLUX_ERR'][outliers], fmt='o', 
                 markersize=4, color='red', alpha=0.8, label='Outliers')

    plt.xlabel('TIME / (BJD - 2457000), days')
    plt.ylabel('PDCSAP_FLUX / e-/s')
    plt.title(filename.replace("_lc.lc", ""))
    plt.grid(False)
    plt.legend()
    plt.tight_layout()
    plt.savefig(filename.replace("_lc.lc", "_outliers.png"))
    plt.show()
# Out:
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/1146318341.py:13: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/1146318341.py:13: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/1146318341.py:13: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/1146318341.py:13: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/1146318341.py:13: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/1146318341.py:13: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/1146318341.py:13: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/1146318341.py:13: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/1146318341.py:13: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/1146318341.py:13: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/1146318341.py:13: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/1146318341.py:13: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/1146318341.py:13: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/1146318341.py:13: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/1146318341.py:13: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/1146318341.py:13: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/1146318341.py:13: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/1146318341.py:13: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/1146318341.py:13: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)
# /var/folders/bm/rws0l5bs0xq65t_b_0jtlh8w0000gn/T/ipykernel_1485/1146318341.py:13: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(filename, delim_whitespace=True)

# %%
import matplotlib.pyplot as plt
import glob
import pandas as pd
import numpy as np
from astropy.timeseries import LombScargle

# Find all .lc files in the current directory
fits_files = glob.glob("*.lc")

for filename in fits_files:
    # Upload the file
    df = pd.read_csv(filename, sep=r"\s+")

    # Remove NaN
    df = df.dropna(subset=['PDCSAP_FLUX'])

    # Basic statistics
    amplitude = df['PDCSAP_FLUX'].max() - df['PDCSAP_FLUX'].min()
    std_dev = df['PDCSAP_FLUX'].std()
    print(f"\n{filename}")
    print(f"Amplitude: {amplitude:.2f}")
    print(f"Standard Deviation: {std_dev:.2f}")

    time = df['TIME']
    flux = df['PDCSAP_FLUX']

    # Lomb-Scargle periodogram
    frequency, power = LombScargle(time, flux).autopower()
    best_frequency = frequency[np.argmax(power)]
    period = 1 / best_frequency
    print(f"Period: {period:.8f} days")

    # Phase folding
    phase = (time % period) / period
    phase_double = np.concatenate([phase, phase + 1])
    flux_double = np.concatenate([flux, flux])

    # Plot both periodogram and folded light curve
    fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=False)

    # Periodogram
    axs[0].plot(1 / frequency, power, color='blue', lw=1)
    axs[0].axvline(period, color='red', linestyle='--', label=f'Best period = {period:.5f} d')
    axs[0].set_xlabel('Period (days)')
    axs[0].set_ylabel('Lomb-Scargle Power')
    axs[0].set_title(f'Lomb-Scargle Periodogram: {filename.replace("_lc.lc", "")}')
    axs[0].legend()
    axs[0].grid(True)

    # Folded light curve
    axs[1].scatter(phase_double, flux_double, s=5, alpha=0.6, color='black')
    axs[1].set_xlabel('Phase')
    axs[1].set_ylabel('PDCSAP_FLUX / e-/s')
    axs[1].set_title(f'Phase-folded Light Curve: {filename.replace("_lc.lc", "")}')
    axs[1].grid(True)

    # Save figure
    output_filename = filename.replace("_lc.lc", "_analysis.png")
    plt.tight_layout()
    plt.savefig(output_filename, dpi=300)
    plt.close()

    print(f"Saved: {output_filename}")
# Out:
# tess2023341045131-s0073-0000000002237045-0268-s_lc.lc
# Amplitude: 143.42
# Standard Deviation: 16.27
# Period: 0.00138866 days
# Saved: tess2023341045131-s0073-0000000002237045-0268-s_analysis.png
#
# tess2023341045131-s0073-0000000002006984-0268-s_lc.lc
# Amplitude: 4048.50
# Standard Deviation: 635.96
# Period: 0.00138865 days
# Saved: tess2023341045131-s0073-0000000002006984-0268-s_analysis.png
#
# tess2023341045131-s0073-0000000002152411-0268-s_lc.lc
# Amplitude: 56.94
# Standard Deviation: 7.24
# Period: 4.40158092 days
# Saved: tess2023341045131-s0073-0000000002152411-0268-s_analysis.png
#
# tess2023341045131-s0073-0000000002008765-0268-s_lc.lc
# Amplitude: 918.08
# Standard Deviation: 196.14
# Period: 0.59533570 days
# Saved: tess2023341045131-s0073-0000000002008765-0268-s_analysis.png
#
# tess2023341045131-s0073-0000000001840666-0268-s_lc.lc
# Amplitude: 72334.00
# Standard Deviation: 12934.37
# Period: 0.08806041 days
# Saved: tess2023341045131-s0073-0000000001840666-0268-s_analysis.png
#
# tess2023341045131-s0073-0000000002234723-0268-s_lc.lc
# Amplitude: 2073.72
# Standard Deviation: 452.05
# Period: 2.46327067 days
# Saved: tess2023341045131-s0073-0000000002234723-0268-s_analysis.png
#
# tess2023341045131-s0073-0000000001750268-0268-s_lc.lc
# Amplitude: 207.01
# Standard Deviation: 34.30
# Period: 0.58242133 days
# Saved: tess2023341045131-s0073-0000000001750268-0268-s_analysis.png
#
# tess2023341045131-s0073-0000000002102329-0268-s_lc.lc
# Amplitude: 4279.00
# Standard Deviation: 426.96
# Period: 0.00138853 days
# Saved: tess2023341045131-s0073-0000000002102329-0268-s_analysis.png
#
# tess2023341045131-s0073-0000000002236015-0268-s_lc.lc
# Amplitude: 274512.22
# Standard Deviation: 47145.40
# Period: 0.00138980 days
# Saved: tess2023341045131-s0073-0000000002236015-0268-s_analysis.png
#
# tess2023341045131-s0073-0000000002334539-0268-s_lc.lc
# Amplitude: 271.84
# Standard Deviation: 37.05
# Period: 0.00139167 days
# Saved: tess2023341045131-s0073-0000000002334539-0268-s_analysis.png
#
# tess2023341045131-s0073-0000000002104696-0268-s_lc.lc
# Amplitude: 953.51
# Standard Deviation: 214.28
# Period: 3.31477045 days
# Saved: tess2023341045131-s0073-0000000002104696-0268-s_analysis.png
#
# tess2023341045131-s0073-0000000002149979-0268-s_lc.lc
# Amplitude: 36842.50
# Standard Deviation: 7036.64
# Period: 1.60776335 days
# Saved: tess2023341045131-s0073-0000000002149979-0268-s_analysis.png
#
# tess2023341045131-s0073-0000000001755406-0268-s_lc.lc
# Amplitude: 185.17
# Standard Deviation: 25.87
# Period: 0.00138865 days
# Saved: tess2023341045131-s0073-0000000001755406-0268-s_analysis.png
#
# tess2023341045131-s0073-0000000001827744-0268-s_lc.lc
# Amplitude: 313.28
# Standard Deviation: 48.72
# Period: 0.43375779 days
# Saved: tess2023341045131-s0073-0000000001827744-0268-s_analysis.png
#
# tess2023341045131-s0073-0000000001947463-0268-s_lc.lc
# Amplitude: 49.96
# Standard Deviation: 6.78
# Period: 0.00138889 days
# Saved: tess2023341045131-s0073-0000000001947463-0268-s_analysis.png
#
# tess2023341045131-s0073-0000000002234692-0268-s_lc.lc
# Amplitude: 374.61
# Standard Deviation: 36.42
# Period: 0.27203293 days
# Saved: tess2023341045131-s0073-0000000002234692-0268-s_analysis.png
#
# tess2023341045131-s0073-0000000002014191-0268-s_lc.lc
# Amplitude: 205.45
# Standard Deviation: 22.69
# Period: 0.00138922 days
# Saved: tess2023341045131-s0073-0000000002014191-0268-s_analysis.png
#
# tess2023341045131-s0073-0000000001950736-0268-s_lc.lc
# Amplitude: 137.56
# Standard Deviation: 16.31
# Period: 0.00138889 days
# Saved: tess2023341045131-s0073-0000000001950736-0268-s_analysis.png
#
# tess2023341045131-s0073-0000000001942416-0268-s_lc.lc
# Amplitude: 659.91
# Standard Deviation: 65.10
# Period: 0.00138847 days
# Saved: tess2023341045131-s0073-0000000001942416-0268-s_analysis.png
#
# tess2023341045131-s0073-0000000002105589-0268-s_lc.lc
# Amplitude: 548.45
# Standard Deviation: 58.45
# Period: 0.00138477 days
# Saved: tess2023341045131-s0073-0000000002105589-0268-s_analysis.png
